# %%
import pandas as pd
import requests
from sqlalchemy import create_engine
import json
import time

# %% [markdown]
# # Artists
# These are the artists preselected for this music festival. We will collect data for all of them to determine the best candidate for each stage.
#
# ## Rage Stage (rap stage)
# - Lil uzi vert
# - Chance the Rapper
# - Trippie Redd
# - YBN Cordae
# - Kanye West
#
# ## Unwind (acoustic/soft rock stage)
# - Jack Johnson
# - John Mayer
# - The Head and the Heart
# - Khrubangbin
# - Rex Orange County
#
# ## The Haus (dance stage)
# - Ricky Retro
# - Flume
# - Louis the Child
# - Hippie Sabatoge
# - Fisher
#
# ## Mud Stage (country stage)
# - Jake Owen
# - Kenny Chesney
# - Thomas rhett
# - Luke Bryan
# - Jon Pardi
#
# ## Mane Stage (most popular)
# - Justin Beiber
# - Ed Sheeran
# - Taylor Swift
# - Lorde
# - Frank Ocean

# %% [markdown]
# ## Generate Authorization Token
# Link for access token used for every endpoint : https://developer.spotify.com/console/get-search-item/
#
# *tokens expire every hour

# %%
#enter access token 
token = "BQA_u73WMo7CzN-LcLDIP_AiAQwvck8ZoiaIYnu78iNTG3l8UjoukLDpvxUBu3rD90fkJJu7K7Gga54IFEJVAlxQgR-2nKhQN0mOep3d2BiG-5z4lfcRAm7xuhVsBwdBfGYjMq80uwTs2AR9ICAYl91bNTbkGJ3GNHf_q6_T8gI15_MQQUFO6CqC6u73D4bxv_z4aQKtk2ocDhG7OdZPhkng5Cp2n69ltq-ufzjjIBqdQSDrvjqCl_S7CL26lZRBYdzUt2SU5GKcnXU"

# %% [markdown]
# ## Populate the Artist Table

# %%
def get_artist(token,artist):
    """
    The following function, takes advantage of Spotify's search endpoint to return an artist's ID
    based off of their name. 
    Parameters
    -----------
    Token- temporary authorization token generated by spotify
    artist - name of the desired artist to get info for
    -----------
    Link for access token: https://developer.spotify.com/console/get-search-item/
    """
    artist_spotify_url = "https://api.spotify.com/v1/search"
    api_token = token #must get token from spotify to access data
    artist_headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    artist_params = {"type": "artist", "q":artist}
    artist_request = requests.get(artist_spotify_url, params=artist_params, headers=artist_headers)
    loaded_data = json.loads(artist_request.text) #get raw data in json format
    follower_count = [] #store follower counts for search results
    artist_dict = {}# store follower count as key and artist ID and name's as value 
    for i in range(len(json.loads(artist_request.text)["artists"]["items"])):
        ID = (loaded_data["artists"]["items"][i]["id"])#artist's unique id
        name = (loaded_data["artists"]["items"][i]["name"])
        followers = (loaded_data["artists"]["items"][i]["followers"]['total'])
        popularity = (loaded_data["artists"]["items"][i]["popularity"])
        artist_dict[followers] = [ID,name,popularity,followers]
        follower_count.append(followers)
        true_artist = max(follower_count)
        true_artist_dict = artist_dict[true_artist]
        return true_artist_dict

# %%
#Populate artist_table using search
artists = ["Lil uzi vert", "Chance the Rapper", "Trippie Redd", "YBN Cordae", "Kanye West", "Jack Johnson", "John Mayer",
           "The Head and the Heart", "Khrubangbin", "Rex Orange County", "Ricky Retro", "Flume", "Louis the Child", 
           "Hippie Sabatoge", "Fisher", "Jake Owen", "Kenny Chesney", "Thomas rhett", "Luke Bryan", "Jon Pardi",
           "Justin Beiber", "Ed Sheeran", "Taylor Swift", "Lorde", "Frank Ocean"
          ]
#create dictionary for dataframe
artists_dict = {
    "artist_id" : [],
    "name" : [],
    "popularity" : [],
    "followers" : []
    }
#iterate through artists to populate dictionary with appropriate data
for x in artists:
    artists_dict["name"].append(x) #pass in name from list
    artists_dict["artist_id"].append(get_artist(token,x)[0])
    artists_dict["popularity"].append(get_artist(token,x)[2])
    artists_dict["followers"].append(get_artist(token,x)[3])

# %%
#assign artists to a dataframe
artists = pd.DataFrame(artists_dict)

# %%
#add to csv
artists.to_csv("artist.csv", index=False)

# %% [markdown]
# ## Populate the Album Table

# %%
def add_albums(album_data,passed_dict):
    """
    This is a helper function for the add_all_albums function. It takes in a request loaded with json and appends it to a dictionary
    passed in. There is no output. 
    
    parameters
    --------
    album_data: json loaded request with album data using the spotify api
    passed_dict: the dictionary this information is being appended to
    """
    for i in range(len(album_data['items'])):
        name = album_data['items'][i]['name']
        passed_dict['name'].append(name)
        ID = album_data['items'][i]['id']
        passed_dict['album_id'].append(ID)
        total_tracks = album_data['items'][i]['total_tracks']
        passed_dict['total_tracks'].append(total_tracks)
        release_date = album_data['items'][i]['release_date']
        passed_dict['release_date'].append(release_date)
        album_type = album_data['items'][i]['album_type']
        passed_dict['album_type'].append(album_type)

# %%
def add_all_albums (artist_id, album_type):
    """
    This function takes in an artist id and album type and returns album data for that artist using the spotify API.
    The datframe will output album ID, number of tracks, duration, release date and album type (single or album).
    For more info about code behind output, see add_albums helper function. Because the Spotify only returns 20 results
    by default, the function has a loop to override this limit and get all of the albums an artist has.
    
    parameters
    --------
    artist_id: spotify artist id 
    album_type: either single or album 
    """
    album_spotify_url = "https://api.spotify.com/v1/artists/{}/albums".format(artist_id)#spotify endpoint to get an artist's albums
    api_token = token #must get token from spotify to access data
    headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    offset = 0 #indicates starting point for album's, add 20 every iteration until all albums are collected
    params = {"include_groups":  album_type, "offset": str(offset)} #keep offset dynamic to get more than 20 albums
    request_og = requests.get(album_spotify_url, headers=headers, params=params)
    loaded_data_og = json.loads(request_og.text) #get raw data in json format
    #create dictionary for dataframe
    albums_dict ={
        "album_id":[],
        "name":[],
        "total_tracks":[],
        "release_date":[],
        "album_type":[]
    }
    add_albums(loaded_data_og, albums_dict) # propogate the dict with the first 20 entries
    #If an artist has more than 20 albums, get them
    while len(albums_dict["album_id"]) < loaded_data_og['total']:
         #repeat request using updated starting point
        offset +=20
        params["offset"] = str(offset)
        request = requests.get(album_spotify_url, headers=headers, params=params)
        loaded_data = json.loads(request.text)
        add_albums(loaded_data, albums_dict)
    output = pd.DataFrame(albums_dict) #read dict to a dataframe
    output["artist_id"] = artist_id#add artist id as foreign key to artist table
    return output

# %%
artist_ids = [x for x in artists['id']]#get artist id from artist table into a list
album_df = pd.DataFrame()# create an empty dataframe to store albums
for x in artist_ids:
    #iterate through each artist and add all of their albums , first finding singles, then finding albums
    album1_df = add_all_albums(x, "single")
    album_df = album_df.append(album1_df)
    album2_df = add_all_albums(x,"album")
    album_df = album_df.append(album2_df)

# %% [markdown]
# *** In the above table, I chose only to show singles and albums, not tracks featured on, however, that data could easily be collected if one desired (ex. "appears_on") See https://developer.spotify.com/documentation/web-api/reference/artists/get-artists-albums/ for more info

# %%
def get_album_popularity(album_id):
    """
    Because the album object returned in the above endpoint isn't the full object, we must pass each album in the 
    database into the "get album" endpoint in order to get popularity for an album. 
    
    Parameters
    -------
    album_id-spotify unique identifier for each album
    """
    album_spotify_url = "https://api.spotify.com/v1/albums/{}".format(album_id)
    api_token = token #must get token from spotify to access data
    headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    request = requests.get(album_spotify_url, headers=headers)
    loaded_test_data = json.loads(request.text) #get raw data in json format
    return loaded_test_data['popularity']

# %%
album_ids = [album_id for album_id in album_df["album_id"] ] #get album ids for each record in the album table into a list
#add popularity to each id
for album_id in album_ids:
    album_df.loc[album_df.album_id == album_id, 'popularity'] = get_album_popularity(album_id)

# %%
album_df.to_csv("album.csv", index = False) #export to csv

# %% [markdown]
# ## Populate the Track Table

# %%
def add_tracks(track_data,passed_dict):
    """
    This is a helper function for the add_all_tracks function. It takes in a request loaded with json
    and appends it to a dictionary passed in. There is no output. This is very similar to the add_albums 
    helper function.
    
    parameters
    --------
    track_data: json loaded request with track data using the spotify api
    passed_dict: the dictionary this information is being appended to
    """
    for i in range(len(track_data['items'])):
        track_id = track_data['items'][i]['id']
        passed_dict['track_id'].append(track_id)
        track_name = track_data['items'][i]['name']
        passed_dict['name'].append(track_name)
        duration_ms = track_data['items'][i]['duration_ms']
        passed_dict['duration_ms'].append(duration_ms)
        explicit = track_data['items'][i]['explicit']
        passed_dict['explicit'].append(explicit)

# %%
def add_all_tracks (album_id):
    """
    This function takes in an album id and returns all of its tracks. Additionally, because only 50 items are returned
    by default, this funtion has a while loop to get all tracks in an album. 
    """
    album_tracks_spotify_url = "https://api.spotify.com/v1/albums/{}/tracks".format(album_id)
    api_token = token #must get token from spotify to access data
    headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    offset = 0
    params = {"limit": "50", "offset":str(offset)}
    request = requests.get(album_tracks_spotify_url, headers=headers, params = params)
    loaded_data_og = json.loads(request.text) #get raw data in json format
    track_dict = {
        "track_id": [],
        "name": [],
        "duration_ms": [],
        "explicit": []  
    }
    add_tracks(loaded_data_og, track_dict) # propogate the dict with the first 50 entries, have to do this to access "total" which is the number of songs returned
    #If an artist has more than 50 tracks in an album, get them
    while len(track_dict["track_id"]) < loaded_data_og['total']:
        offset +=50
        params["offset"] = str(offset)
        request = requests.get(album_tracks_spotify_url, headers=headers, params=params)
        loaded_data = json.loads(request.text)
        add_tracks(loaded_data, track_dict)
    output = pd.DataFrame(track_dict) #add tracks to a dataframe
    output["album_id"] = album_id #assign album_ids for each track as a foreign key
    return output

# %%
def make_track_table(album_ids):
    """
    This function simply takes the add_all tracks function and makes sure requests are spread out properly. It does
    so by making a maximum of 400 requests and then waiting 100 seconds to make another one. 
    
    """
    track_df = pd.DataFrame()
    counter = len(album_ids)# make counter length of id list
    increment = 400 #increment number of requests by this
    lower = 0 #set the lower bound to 0
    upper = increment
    while counter > 0:
        for x in album_ids[lower:upper]:
            track1_df = add_all_tracks(x)
            track_df = track_df.append(track1_df)
        lower += increment #add the increment to the lower bound
        counter -=increment # decrement the counter
        upper = lower + min(increment, counter)#set upper to either the increment or the counter value if it's less than the increment to prevent index out of range
        time.sleep(100)
    return track_df

# %%
album_ids = [x for x in album_df['album_id']] # get all album ids in the album table
track_df = make_track_table(album_ids)# propogate the track table with tracks

# %%
def get_tracks_popularity(track_ids,df):
    """
    Accepts a list of track_ids and a dataframe and then adds the popularity to those tracks. 
    Max number of tracks it can take is 50 tracks. This must be used because the "get an album's tracks"
    endpoint used in the add_all_tracks function only returns a limited track object, meaning popularity
    is excluded.
    
    """
    track_ids_urls = ",".join(track_ids)
    track_spotify_url = "https://api.spotify.com/v1/tracks?ids={}".format(track_ids_urls)
    api_token = token #must get token from spotify to access data
    headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    request = requests.get(track_spotify_url, headers=headers)
    loaded_test_data = json.loads(request.text) #get raw data in json format
    for num, track_id in enumerate(track_ids):
        df.loc[df.track_id == track_id, 'popularity'] = loaded_test_data['tracks'][num]['popularity']

# %%
def add_popularity_to_track(df,outer_lower, outer_upper):
    """
    takes the get_tracks_popularity function above and ensures that requests are properly created.
    Because only 50 albums can be passed in at once, the function breaks down a list of album_ids passed
    through into groups of 50 and runs them until the upper bound is reached.
    
    parameters
    ------
    df-dataframe to be iterated through, assumes dataframe has a "track_id" column with track id's
    outer_lower-lower bound of the dataframe index this function should iterate through is
    outer_upper-upper bound of the dataframe index this function should iterate through
    """
    inner_counter = outer_upper# make counter length of id list
    inner_increment = 50 #increment number of requests by this
    inner_lower = outer_lower #set the lower bound to 0
    inner_upper = inner_increment
    while inner_counter >= outer_lower:
        current_tracks = [x for x in df["track_id"][inner_lower:inner_upper]]
        get_tracks_popularity(current_tracks,df)
        inner_lower += inner_increment #add the increment to the lower bound
        inner_counter -=inner_increment # decrement the counter
        inner_upper = inner_lower + min(inner_increment, inner_counter)#set upper to either the increment or the counter value if it's less than the increment to prevent index out of range

# %%
def populate_track_table_popularity(df):
    """
    takes a dataframe and applies the add_popularity_to_track function above and properly 
    spaces out requests, making 500 requests and then resting 100 seconds. 
    
    parametrs
    ----------
    df-dataframe to be iterated through (assumes track_id is field)
    
    """
    outer_counter = len(df['track_id'])
    outer_increment = 500
    outer_lower = 0
    outer_upper = outer_increment
    while outer_counter > 0:
        add_popularity_to_track(df,outer_lower,outer_upper)
        outer_lower += outer_increment #add the increment to the lower bound
        outer_counter -= outer_increment # decrement the counter
        outer_upper = outer_lower + min(outer_increment, outer_counter)
        time.sleep(100)

# %%
populate_track_table_popularity(track_df)#get popularity

# %%
def get_tracks_audio_features(track_ids,df):
    """
    Accepts a list of track_ids and a dataframe and then adds the audio features to those tracks. 
    audio features added are tempo, energy, acousticness and danceability.
    
    parametrs
    ----------
    track_ids-a list of tracks to get audio features for
    df-dataframe to append these features to (assumes track_id is a field)
    """
    track_ids_urls = ",".join(track_ids) #reformat to be accepted by the url
    track_audio_features_spotify_url = "https://api.spotify.com/v1/audio-features?ids={}".format(track_ids_urls)
    api_token = token #must get token from spotify to access data
    headers = {"Authorization" : "Bearer %s"%api_token, "Content-Type": "application/json"} 
    request = requests.get(track_audio_features_spotify_url, headers=headers)
    loaded_test_data = json.loads(request.text) #get raw data in json format
    for num, track_id in enumerate(track_ids):
        df.loc[df.track_id == track_id, 'tempo'] = loaded_test_data['audio_features'][num]['tempo']
        df.loc[df.track_id == track_id, 'energy'] = loaded_test_data['audio_features'][num]['energy']
        df.loc[df.track_id == track_id, 'acousticness'] = loaded_test_data['audio_features'][num]['acousticness']
        df.loc[df.track_id == track_id, 'danceability'] = loaded_test_data['audio_features'][num]['danceability']

# %%
def add_audio_features_to_track(df,outer_lower, outer_upper):
    """
    takes the get_tracks_audio_features function above and ensures that requests are properly created.
    Because only 50 albums can be passed in at once, the function breaks down a list of album_ids passed
    through into groups of 50 and runs them until the upper bound is reached.
    
    parameters
    ------
    df-dataframe to be iterated through, assumes dataframe has a "track_id" column with track id's
    outer_lower-lower bound of the dataframe index this function should iterate through is
    outer_upper-upper bound of the dataframe index this function should iterate through"""
    
    inner_counter = outer_upper# make counter length of id list
    inner_increment = 50 #increment number of requests by this
    inner_lower = outer_lower #set the lower bound to 0
    inner_upper = inner_increment
    while inner_counter >= outer_lower:
        current_tracks = [x for x in df["track_id"][inner_lower:inner_upper]]
        get_tracks_audio_features(current_tracks,df)
        inner_lower += inner_increment #add the increment to the lower bound
        inner_counter -=inner_increment # decrement the counter
        inner_upper = inner_lower + min(inner_increment, inner_counter)#set upper to either the increment or the counter value if it's less than the increment to prevent index out of range

# %%
def populate_track_table_audio_features(df):
    """
    takes a dataframe and applies the get_tracks_audio_features function above and properly 
    spaces out requests, making 500 requests and then resting 100 seconds. 
    
    parametrs
    ----------
    df-dataframe to be iterated through (assumes track_id is field)
    
    """
    outer_counter = len(df['track_id'])
    outer_increment = 500
    outer_lower = 0
    outer_upper = outer_increment
    while outer_counter >= 0:
        add_audio_features_to_track(outer_lower,outer_upper)
        outer_lower += outer_increment #add the increment to the lower bound
        outer_counter -= outer_increment # decrement the counter
        outer_upper = outer_lower + min(outer_increment, outer_counter)
        time.sleep(100)
    print("done")

# %%
populate_track_table_audio_features()#get audio features

# %%
track_df.to_csv("track.csv", index=False)#export to cev

# %%
mistake_df = pd.read_csv("data for analysis/track.csv")

# %%
mistake_df[mistake_df.popularity.isnull()].iloc[499:550]
# Out:
#                     track_id  \
# 5049  2rLYkfJSgTPtOTLjYEdozL
# 5500  6pqpSaH7JggGPKPRhMiN1x
# 5501  0duOOCLT6zJ5utB1SloK41
# 5502  2sbtixigDCbjXBTMRSEECS
# 5503  0A8cJT245zXmWhcQWbtmw3
# 5504  0Nf53RDPZEjFrQE4B5n6Vf
# 5505  5flMobLspM4oVHpNmMkejM
# 5506  3LlESXmjxOrMmAbkSws3AT
# 5507  3paU6Do80sHrJdJhk6kYNg
# 5508  6Pxy5nH3meSvv3tnDsHfwd
# 5509  3qVvNO1MksU6qnvJgco3uq
# 5510  3yYlHul3JdlGHLRrG6BsXw
# 5511  3YYwrOdeMEvmHBWHJ0TmB6
# 5512  1kG1a1eoAgg2WS4gXeyFsl
# 5513  4tz7xNwEb1g34e2UnP46v3
# 5514  2nE6CuMPZ4I9kHM9PUnKaf
# 5515  69lMFbj9GmdjY7cx5JxRlq
# 5516  5gcH65ZS1XaJo4jFHSV3h1
# 5517  0qTaU3TBPc0YKNN87THfvN
# 5518  0PfxFasOH971bzmGmA8vJn
# 5519  5Wgt1TBCwfIRRcVIjdNjI3
# 5520  6D5yF3qnvGqVrV5gJ0nfhT
# 5521  7i6cPofOjHfRrM22tLKgeN
# 5522  0htK81PAiVaSXbGPTcEzvr
# 5523  3I4QOvltiKcMu3xmnQjEct
# 5524  0PXCdhnm9fRgrIgoMcteZa
# 5525  0zL76omZWytdTtyXKVfuDw
# 5526  4YBDSEzVNQbvCvVIWNtruF
# 5527  4iSN72L6xCM7vQZR2I9Suz
# 5528  3VDX4CCJWbRXBKuW5IY5R9
# 5529  0dtMnnWhm2AXVxjJy5hUPe
# 5530  5bMWY1u9ghi4X6fIAsQRaC
# 5531  6IIcLzR05sN1gk4ngzz7Kk
# 5532  7kEN6uPEaCTATwQKagVcVE
# 5533  1qXjolYMICsnISl8xZAbA2
# 5534  5u64RlrnvvbtNh6R0EMh6o
# 5535  5a0OGWGpyPluxyHYdbz303
# 5536  7FylTZ7KlODhW6VCKIwaBJ
# 5537  01FqUF3GUF5IR4ZRnClxdG
# 5538  1a4zjO7deeOWgIlA190mGU
# 5539  6pgZBGVEIqDZX8oIV1E66S
# 5540  3M1dYoJkBHjEFyPkASUvqN
# 5541  30QxqmT6YAwGlJ3HiM1paE
# 5542  0YDm7O5Cx3CbSalyexDaCt
# 5543  0pkZBn6OmsTDsYsRJQCyL0
# 5544  2ek4XPZRNFeasc7EZuC4b1
# 5545  4H8DlsD6NSGlEwCr3x39Nl
# 5546  7GRgbc1Dj2NBiZpCc33c7W
# 5547  6ie2Bw3xLj2JcGowOlcMhb
# 5548  7eElVgPcxDqmgGrSwVFI74
# 5549  02oAUzv4M0ItuTDy2RT3IT
#
#                                                    name  duration_ms  \
# 5049                           I Almost Do - Commentary        52625
# 5500                          Homemade Dynamite - REMIX       214254
# 5501  Homemade Dynamite (Feat. Khalid, Post Malone &...       214254
# 5502                        Green Light - Chromeo Remix       247933
# 5503                        Flicker (Kanye West Rework)       252773
# 5504                                Yellow Flicker Beat       232506
# 5505                                             Royals       190185
# 5506                                            400 Lux       234286
# 5507                Team - Live At The 2013 ARIA Awards       232096
# 5508                                             Royals       190185
# 5509                                       Tennis Court       198907
# 5510                                       Tennis Court       198907
# 5511                                      Swingin Party       222362
# 5512              Buzzcut Season - Live In Concert 2013       251609
# 5513               Swingin Party - Live In Concert 2013       233984
# 5514                     400 Lux - Live In Concert 2013       272859
# 5515                      Royals - Live In Concert 2013       222974
# 5516                                             Royals       190185
# 5517                                            Bravado       221408
# 5518                                             Royals       190185
# 5519                               Million Dollar Bills       138210
# 5520                                      The Love Club       201433
# 5521                                        Biting Down       213665
# 5522                         Bravado - Fffrrannno Remix       221865
# 5523                                        Green Light       234652
# 5524                                              Sober       197235
# 5525                                  Homemade Dynamite       189796
# 5526                                         The Louvre       271088
# 5527                                          Liability       171727
# 5528                             Hard Feelings/Loveless       367391
# 5529                               Sober II (Melodrama)       178639
# 5530                                 Writer In The Dark       216610
# 5531                                           Supercut       277506
# 5532                                Liability (Reprise)       136019
# 5533                                     Perfect Places       221874
# 5534                          Homemade Dynamite - REMIX       214254
# 5535                                        Green Light       234652
# 5536                                              Sober       197235
# 5537                                  Homemade Dynamite       189796
# 5538                                         The Louvre       271088
# 5539                                          Liability       171727
# 5540                             Hard Feelings/Loveless       367391
# 5541                               Sober II (Melodrama)       178639
# 5542                                 Writer In The Dark       216610
# 5543                                           Supercut       277506
# 5544                                Liability (Reprise)       136019
# 5545                                     Perfect Places       221874
# 5546                          Homemade Dynamite - REMIX       214254
# 5547                                        Green Light       234652
# 5548                                              Sober       197235
# 5549                                  Homemade Dynamite       189796
#
#       explicit                album_id  popularity  tempo  energy  \
# 5049     False  4jTYApZPMapg56gRycOn0D         NaN    NaN     NaN
# 5500     False  5oj6N6xLROv6pLctdOhENm         NaN    NaN     NaN
# 5501     False  1h8c5s02EHw89eddxInlul         NaN    NaN     NaN
# 5502     False  7IbLnQpLU1n85xtPPr9dbR         NaN    NaN     NaN
# 5503     False  112eEMM7VwHVEknE4hHjjY         NaN    NaN     NaN
# 5504     False  7sg5iqMiDrM2aJqLAmv83V         NaN    NaN     NaN
# 5505     False  2eDQDP6uhkBOtQKctBWXhN         NaN    NaN     NaN
# 5506     False  2eDQDP6uhkBOtQKctBWXhN         NaN    NaN     NaN
# 5507     False  6Ukmi7AfxNAUrwmVWBwJ1a         NaN    NaN     NaN
# 5508     False  2Pf42OiIQLrA9swcdJGFqv         NaN    NaN     NaN
# 5509      True  2Pf42OiIQLrA9swcdJGFqv         NaN    NaN     NaN
# 5510      True  7EUGqK1EQw2k02BFR1hu47         NaN    NaN     NaN
# 5511     False  7EUGqK1EQw2k02BFR1hu47         NaN    NaN     NaN
# 5512     False  0CvwwhkzMUiDm8cQqtN6Ys         NaN    NaN     NaN
# 5513     False  0CvwwhkzMUiDm8cQqtN6Ys         NaN    NaN     NaN
# 5514     False  0CvwwhkzMUiDm8cQqtN6Ys         NaN    NaN     NaN
# 5515     False  0CvwwhkzMUiDm8cQqtN6Ys         NaN    NaN     NaN
# 5516     False  0u5tyaipbUJjHgkceoPtM7         NaN    NaN     NaN
# 5517     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5518     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5519     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5520     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5521     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5522     False  2RHYxz7blfHR3iVxPtc25G         NaN    NaN     NaN
# 5523     False  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5524      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5525      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5526     False  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5527     False  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5528      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5529      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5530     False  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5531     False  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5532      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5533      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5534      True  4oCGmYsAQOWt2ACWTpNUU6         NaN    NaN     NaN
# 5535     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5536     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5537     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5538     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5539     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5540     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5541     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5542     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5543     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5544     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5545     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5546     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5547     False  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
# 5548      True  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
# 5549      True  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
#
#       acousticness  danceability
# 5049           NaN           NaN
# 5500           NaN           NaN
# 5501           NaN           NaN
# 5502           NaN           NaN
# 5503           NaN           NaN
# 5504           NaN           NaN
# 5505           NaN           NaN
# 5506           NaN           NaN
# 5507           NaN           NaN
# 5508           NaN           NaN
# 5509           NaN           NaN
# 5510           NaN           NaN
# 5511           NaN           NaN
# 5512           NaN           NaN
# 5513           NaN           NaN
# 5514           NaN           NaN
# 5515           NaN           NaN
# 5516           NaN           NaN
# 5517           NaN           NaN
# 5518           NaN           NaN
# 5519           NaN           NaN
# 5520           NaN           NaN
# 5521           NaN           NaN
# 5522           NaN           NaN
# 5523           NaN           NaN
# 5524           NaN           NaN
# 5525           NaN           NaN
# 5526           NaN           NaN
# 5527           NaN           NaN
# 5528           NaN           NaN
# 5529           NaN           NaN
# 5530           NaN           NaN
# 5531           NaN           NaN
# 5532           NaN           NaN
# 5533           NaN           NaN
# 5534           NaN           NaN
# 5535           NaN           NaN
# 5536           NaN           NaN
# 5537           NaN           NaN
# 5538           NaN           NaN
# 5539           NaN           NaN
# 5540           NaN           NaN
# 5541           NaN           NaN
# 5542           NaN           NaN
# 5543           NaN           NaN
# 5544           NaN           NaN
# 5545           NaN           NaN
# 5546           NaN           NaN
# 5547           NaN           NaN
# 5548           NaN           NaN
# 5549           NaN           NaN

# %%
mistake_ids = [x for x in mistake_df[mistake_df.popularity.isnull()].track_id]

# %%
low = 100
high = 150
while high <= 550:
    get_tracks_audio_features(mistake_ids[low:high],mistake_df)
    get_tracks_popularity(mistake_ids[low:high],mistake_df)
    low+=50
    high+=50

# %%
mistake_df.iloc[5000:]
# Out:
#                    track_id                                            name  \
# 500  13K3BqdOYYMepkNQPWL1DZ                                          Target
# 501  34S4m6c5KQkPBl7Am9uQQa                    Man Down (feat. Chris Brown)
# 502  0aJP5iqcwIMrRerm3SVU9a                                     2 Tone Drip
# 503  4mqsUZrSOnMhexy1unMUbv                                       Feel Like
# 504  6RFr8aTQDY890SeEPxT7la                        Cake (feat. Wiz Khalifa)
# ..                      ...                                             ...
# 595  0dU7xLPDI059t0NzyuDWRV                                   Heard 'Em Say
# 596  5IgQ0uG7HMn2sEKmTDJiGM                           We Can Make It Better
# 597  5Merj2SWlm2pwudOyNrKZg              Diamonds From Sierra Leone - Remix
# 598  290DH5BclWLihECLilse0o  Diamonds From Sierra Leone - Remix feat. Jay-Z
# 599  0Gsj2iZerDbXbU0G1IHuB2                                     Gold Digger
#
#      duration_ms  explicit                album_id  popularity    tempo  \
# 500       142050      True  6l4itLa2SkBAVBASZ2WKFv        55.0  161.949
# 501       165722      True  6l4itLa2SkBAVBASZ2WKFv        42.0   74.970
# 502       181538      True  6l4itLa2SkBAVBASZ2WKFv        47.0  149.954
# 503       185456      True  6l4itLa2SkBAVBASZ2WKFv        42.0  142.005
# 504       165214      True  6l4itLa2SkBAVBASZ2WKFv        43.0  159.952
# ..           ...       ...                     ...         ...      ...
# 595       206453      True  1MJmRFANebEoc7kqCT9Aai         8.0   94.981
# 596       231920      True  1MJmRFANebEoc7kqCT9Aai         7.0   96.856
# 597       215946      True  67FtWExClJpODNRGtZBas6        26.0   95.880
# 598       214200     False  2i2w7w95NRbLd5BKYU9RCD        30.0   96.669
# 599       208040      True  00Ez7sCJE0zJMpCg1wPigP        37.0   92.508
#
#      energy  acousticness  danceability
# 500   0.643        0.0114         0.833
# 501   0.609        0.0138         0.747
# 502   0.767        0.1920         0.857
# 503   0.523        0.1070         0.931
# 504   0.550        0.0147         0.892
# ..      ...           ...           ...
# 595   0.681        0.0581         0.692
# 596   0.683        0.1630         0.668
# 597   0.853        0.2850         0.526
# 598   0.850        0.2640         0.601
# 599   0.700        0.0173         0.704
#
# [100 rows x 10 columns]

# %%
album_mistake_df = pd.read_csv("data for analysis/album.csv")

# %%
[x for x in album_mistake_df["album_id"] if x not in mistake_df['album_id'].unique()]
# Out:
# []

# %%
mistake_df['album_id'].unique()
# Out:
# array(['4iz9Pqwpw8HljZei6XFCGd', '4uTOUYhLrGRKkfxfPKTkuy',
#        '5UL4JeebFRM3CwLfk7ZAlh', '2WyjmS6PEAE2V9oh5So588',
#        '49K82qcZN4u109e6Zw8io1', '7jV7IRYpTLmTJe7uZXZCZh',
#        '1BMfByaGjaWoSraUSfCQQh', '435lskCkjbKTmpmescTIpI',
#        '64eE6FnNj7UJ9LEkN4EbvS', '7hVFsGvQ1apmp4EAldMwID',
#        '3uDbCFQLj4zd7uqXQscEIt', '51HrCduoCfmUtzrYHf7onw',
#        '0KaQCJshy3j3TKCu59Yh6X', '6x8tzop53PDl2tvjIXB9a0',
#        '3dIJfqjcEFjBlLoN1B8LU3', '749Tz64P7CRASs0uiKIEGU',
#        '5RwV0u1A3sQELA5e5llaKs', '7ud6EsFurWtzF3lzB8YqNI',
#        '3G9US0Byt1UldeKifKPIwa', '2LLktilGbQD95Bqt6ZXJX7',
#        '1kLcxp6VxnDTXgAPCFTeiy', '2xjjRh1xKSDBq6vE5XiroA',
#        '3TBDsoyXYFtAciT0bQjKDl', '0fEO7g2c5onkaXsybEtuD2',
#        '7IyoGB8J31fvQDwGtHAq9m', '0zicd2mBV8HTzSubByj4vP',
#        '3JeNGvA44e3pPkl4axzIjZ', '733e1ZfktLSwj96X5rsMeE',
#        '2DiIYE1nwRB4JW42HoXBnu', '6LX75kNicFqjjiAOeZgN67',
#        '7mgdTKTCdfnLoa1HXHvLYM', '5WrbKW1nRN4vSsu70uizxX',
#        '432608DLpP0hExluDkY3Yh', '49bXZtlI5kQSqQMSCnSaWO',
#        '5MKInakULmoBNApeB2ZB3A', '4tvWn8rsp56lzyMKV409Og',
#        '3oa90TbTT5bJwCUJ5fDmvu', '6RQhltF3miWYkdfDT0JIbG',
#        '3vmi56TsSbDKwnN9ZnWROz', '5pQOfgCqpu4RrJAfQToFa8',
#        '53vsM5JN76NXiv7aj4PXK1', '3aMsYP1nhJx0rJ6DX6bvAe',
#        '3SQBhLa7AkmCNWuDmJpRkD', '4OtCzrYbNZp8c5czzAJeUP',
#        '7bgi7zCoDsZdlLKPonHZqP', '7niOG7nbuUzXSvNtJruogj',
#        '71QyofYesSsRMwFOTafnhB', '2VBcztE58pBKjIDS5oEgFh',
#        '6bUsvxMAuR8NXG2ujCU4yi', '1fBcjfHpvjKj8ofg8NAhmM',
#        '2fKJAIWnOn6VQwnpNl3Bso', '2orYogfKeURqyS1hRP1vZ4',
#        '4wjwgVjWzrMv7Tp8w9Rmnd', '0yiQkEA0kGrkvhlQkpu30d',
#        '2CNIeGAVIK6FSWiQK0MBLS', '6ayA69JRJzCvDGeZir7Ysr',
#        '0wb2DaHDhLUUS5RRFa26U9', '6DNpFe4WAWTa84I6JBuey6',
#        '6uVGwJBJrKEunfTqWCDyn2', '0zLTh5nuGUWbCPPiaeAPnb',
#        '2qLbbPRZS6rQo44nXH8Z9H', '2HLwLpyTKv5C2ezhxYuQ5U',
#        '2nXb6mFjYhHmcyhBV6LZ30', '6ZhOC5xr3JOdr7hmQTSqyR',
#        '2iVrW4u0oPERFW5tpkvNAw', '6sk39wHqIBBxwBvqSj7jl4',
#        '5HxAReosORRcreO0KH6kve', '6cd8LVLiKVM3RYI42HkapE',
#        '3wfGIfiVa5764OJIdd8IwL', '5jpVsmuJfZl3gGvfPLHyiA',
#        '3M2PJCMOf07WgD9r71asB5', '2CH8od3NBJpsvqTdY3H1HH',
#        '2oeslyXeC2BH0UXSv5O1GH', '7jQXJtOgQsR8NpLdKZ8iv1',
#        '0D2ArJUb7VQ2tVmsHZohUZ', '7wkvOZR4wvDuu1dQYndTNO',
#        '7emMyaAzr0nZ7yP8P02zdu', '2q3JHVSCf7EDm6hYKTYbgB',
#        '14ykV7sI2kUNPUgQbbAQIS', '3UvaDivs0zQN3B1D4v3wzf',
#        '322J4HMRGXW1AIczWJkPfU', '5Hsaxc6a2GWPAqXttPFbY0',
#        '0tKX7BLXiiRgXUKYdJzjEz', '2sdJtAHONSZdHAqI3W9TrL',
#        '11vLnrFGWQRbonR6wFuCf8', '30BzlWP45oDctXuwQWzOIo',
#        '6qRbGZqJ3aQY8N8bcHc1ug', '214f4uAY0p2KgY7Fl4fBgk',
#        '55XA1uIQSqmlTBkVVx6ptz', '7ae73nWyKrrH9wwGm97RIA',
#        '7Ddeaiib1prp689aHF0ILF', '2aNIYQ7ewBTpvT2gbuE903',
#        '2EIrVowJlZncpA9aKjohb9', '34t7kwuWKe4iyoHeqjglsg',
#        '6Pb7PMZtW0fuEM1lCGvCDu', '1fis1tOVDsffi2Q9hkBLfC',
#        '6l4itLa2SkBAVBASZ2WKFv', '7Jq7aQPj4z2Rrh51nbBu4U',
#        '185Tm1g5U7eMOrm3m9SQUh', '1mTS3TI1DYu3U25RAVwwBv',
#        '6ggnUqpjfkDULwX0dr164j', '0xFDwqM0pXFS7Bcz8raNOE',
#        '2hTxwsnzU7h15XcAUWSME8', '1PkFK7nfqX9jEMaIA8O12Y',
#        '0zepz9d3dDgoEE8Rzjs8G2', '5oVUniYBHNdw6LKSQac5iH',
#        '6PMuXABPVPf11EgTxrjroO', '7yBl4uFyJzH48Vy6tPieXL',
#        '2ar6Yxkh6psvQOrGqk248v', '2ZQcUtW7OGSsd6LQNcYQoh',
#        '0hWnFKG2S9mCzhbQNmFAGe', '0hmFRR0pDSZIAvoJqEFSKv',
#        '1A2K7r06jBl3iUo3kMYNnb', '3gFzpNzh1Kb48CwztWkeLu',
#        '0MhulrpJg1iyEuQVHQv9Su', '0uAPk9JTejYKvlEoxayaFZ',
#        '4krLrtPXP4zr2r03Q2ZUHM', '5dknqUzmNc6HSL3DhoBfey',
#        '31dBitfDGugqFHLKrUT3rt', '0GAyWmXVYXKFknfJk3645G',
#        '0hPcqGawJMPUeypvRAsIvJ', '25Ou2ydwOg3kOiqjIIhFZY',
#        '7qc7uP4et4ATd9YYUN2Azh', '2eITP5J0vgLdYyKDSiJ9Vu',
#        '5lNW2UpJq0KKrnProitxv3', '2DeoUIL9jsa6YlaQQPFUzG',
#        '2QW6OefeHoT7ROJHvc2cDS', '2ov5qgl5py9l26e9Shudk5',
#        '6RiEJCCIfuoIVkFllfVj3N', '34Zab56cGWioE5YMwvOf8d',
#        '5Q2ds2vF2R1uXFa95oBegx', '7pm0pWEb4BQhsjIGa6PlwQ',
#        '0kOhWJfxRY20tw5b22hIYu', '1Q145zB2X6JTHbcP1BClDn',
#        '3yqEuCToss6oo6GZSDbWF1', '6myPpFt3Lq4ZSyFziQqzJT',
#        '5xLxlrkwSh0gMp6LhpvzsC', '6umfVigUSdSO4uq3tank7R',
#        '4gP3i5bDhtPGAnMBpmQdfd', '08wsihQJihbKQxzhANr5Vr',
#        '3MtVlwzc3GHBYZN0bIeSKv', '3SOhfJ744Gf0XuIkcrSQ12',
#        '2hR0mZCxXkZ48dmq7xEb2O', '2KjGV5H2S2tXVdOJFXdYvd',
#        '7lKGEnNpBNR8kjXfbs9c66', '1MJmRFANebEoc7kqCT9Aai',
#        '67FtWExClJpODNRGtZBas6', '2i2w7w95NRbLd5BKYU9RCD',
#        '00Ez7sCJE0zJMpCg1wPigP', '5Us5l37SEZyye4CvKFV1Eq',
#        '1ckw6eoYQj8PejLBuHQQnz', '2WGzSy4sJ4etXpz9mk6zA6',
#        '5F22SSKyE4rwA3YN6ncpXF', '35EZOI24V46r3DBwgMSqOd',
#        '6cqyCuFvhQ84b8kuMSw16L', '252A7DJaAnMW1JfpKBWtfu',
#        '75rbDc9Ik00r57svAKhG0w', '5xtyFs4XoMvAxDGCAN3gds',
#        '7cflbZkQ7lzeSWqME0RhRF', '21ys97Ivvq8UPdi16XgQ70',
#        '51O2IPx2BYdgXykPYSVYVe', '1qHp7kuS94RA4vovXdnGTL',
#        '0trjZp7SXk1jKZKko0nck0', '1aUiDjuQU4qo8vZTHjCqfJ',
#        '3orLWTn3vQkmcWD5aGcUTC', '0FgZKfoU2Br5sHOfvZKTI9',
#        '6pwuKxMUkNg673KETsXPUV', '2Ek1q2haOnxVqhvVKqMvJe',
#        '7gsWAHLeT0w7es6FofOXk1', '7u6Q36bDPiNegcQ7u69bKq',
#        '7D2NdGvBHIavgLhmcwhluK', '0A3g19AGFd9Qe3rAIkP8e0',
#        '2P2Xwvh2xWXIZ1OWY9S9o5', '1YwzJz7CrV9fd9Qeb6oo1d',
#        '4P63UgNDUcF11MnWzyvVrh', '2IC7s3KVP6ottxQUnkm4eS',
#        '7mCeLbChyegbRwwKK5shJs', '0OcMap99vLEeGkBCfCwRwS',
#        '0eZRIt3Ht1IuMXsr0QR8OY', '6Oa0ZYzr4VdFIz3zNmYJYQ',
#        '20r762YmB5HeofjMCiPMLv', '6klUp8sQyRXGuJhqZu4PG3',
#        '5ykOQlHaE5ZRxMibfI75YW', '3WFTGIO6E3Xh4paEOBY9OU',
#        '2EvIPfiWOIxIZ193E8sK8w', '4SZko61aMnmgvNhfhgTuD3',
#        '5fPglEDz9YEwRgbLRvhCZy', '6V0srAdQfEIarFvIxAYilH',
#        '4WNXpeZR1jc2NFgOAeyLMB', '0FnTw6TY6iB5AHATPzCYkd',
#        '0veuYKXCayS7oIfyqlibeR', '5ll74bqtkcXlKE7wwkMq4g',
#        '4yJqrqT2BpuXLj5BMJlAXR', '0Ds6i3h0F9RcYIKAD5Olum',
#        '4Uv86qWpGTxf7fU7lG5X6F', '3lQePoIm6iNQIiZkCYxCy0',
#        '3KNkqgPidrZtALysyposxI', '43gQi7MWkI4NZXj4BnHpi7',
#        '585PMrrTgTCtIbyX7WRQt0', '3VfqKMnjoIsXjBdbKRpGWu',
#        '1uzMDh8QFZHkCw4fFsqQFr', '2HLWqyHfpx1npfiFSMosuZ',
#        '10QI28MK6vQxxNJoGTjKq4', '4wbbSmGoUbLydE7vKKFeAB',
#        '3ljXg8nByPoxVN7QFdo9Dr', '3dDm3GIjNzQuloufZifyqs',
#        '3kRKSZttQFwXgdWAwh3oMJ', '0qgQlHJZ3F8AGPbrwEPoRJ',
#        '1G2p5VxNqA3OyHVnYu2Gi6', '7l9PN5ec8elW9a2iniJTvL',
#        '6YZCuLcI6iw0wAbxIyw9R3', '2hhNhFoNM6hUuleHFo8J3r',
#        '0Q35LuIC8z1wChZw20Leaz', '0SHXUFH6yhCvBRrvg3hsV3',
#        '1fD2qxIR0IHqZtASSg7ySc', '4H6Vj926e1tVCMl82zMIXR',
#        '4nvgSs9EQXS5AIwprqq8OU', '3Mv2xv8Fsr5ZJc7ge7bR93',
#        '4wIgXctxGSipzlN3AU1eMP', '7xEHscj7Wr1C2e7rt1sdDp',
#        '2zenKRTGjKhRZE4e3Bp0Nf', '4547iU6Wn0viCDAVUroaKa',
#        '16TIFjdID7825maP9BWQrn', '1YBsTcWJI57G7lTf4nxLu3',
#        '00OA5YSK62B4vQnnJCXZrl', '40v2pysbu1XsWOpwCyhhpp',
#        '7awawZPDXZOUKIN814tSWf', '6VYDOztyaK6OeaLAFPuH9r',
#        '0jjvaD993rgEITVcHN6aqc', '2Rsnwa1yRhsktBsy3WZDi4',
#        '1a15dDOiwz5ebSxk1ZeFB5', '3z0ah0DTRYEZDbi5MWmBnX',
#        '3da6Ihr5l6xjOCDs5sTXIu', '61427AKV7p3p30uvrniI4L',
#        '00Me6BWP9P7j6m8x5cbcpV', '797PJRUOp9NICoGRKjpAnx',
#        '0N9g1klLNTWcRharbEVsPB', '0IsTL8lnrHuNvpMPawAFRs',
#        '2WhNmY6H4EREyAV5J5vgsv', '3mQJ5u7qqfIZK4KfyJxLOd',
#        '4ixba2RP3g7Mq41VVk83Rx', '5sepHXGobkchZMKuYa7s5O',
#        '3fa8r86AofGDNs1S2d3xgz', '7pdetUmzDu3AG8SFzR5Ar5',
#        '7t7NcQkBgeFVIWkyTlPr7T', '3Jl7i9Vo0Ht4co9SqTFjQy',
#        '0kYv61g7n6ZPe2TVaIBeeJ', '2B9q4KPjOEYu885Keo9dfX',
#        '3pFq2xOJX2Cm93vuVrBO0z', '7tTc46dNdE6GGuiQsssWxo',
#        '3Tt1mdezAOx4vjcOovItbV', '7LQhG0xSDjFiKJnziyB3Zj',
#        '38kXZAqIY0MQgu0nDAwW1j', '2K9N8V0ORKpkpTOxhcFnud',
#        '6tBi2jfr3vkr3qLQAxZ1Tr', '2zYmSJZxBTCvDYBAEcixyV',
#        '5KvmuOTWNRFPAQdz0KRPcf', '35Kv9CZURVdrejZ5jsL8Xn',
#        '2KW0btTto2vHPpnGdWZTaI', '6AvyYJ6uOBNGvpQrJCHbV1',
#        '5fEgDYFPUcvQy21TYoLEZ0', '0i6oIJ53snlnCd7f2J5dJy',
#        '5GkyQHN2jO9L05VV0gBnGH', '5uBT48jKnO59Oylf08pJJA',
#        '305TANxsPTFkiqS4cEilx1', '7itsnGWJ6GLoTuU6U90uvV',
#        '6DcQ0gH9Hxp42PvNBoo5gX', '1BCSXIQn5NuqM19MjZuOQY',
#        '1kf0hXvUKd4qkKGrWBws7q', '17PEr75OpNpwetfh9n0TYM',
#        '4y0ApnEyNmjPlrnhovDrAb', '0jZFu2tihRJ65iYAo0oOtP',
#        '712VoD72K500yLhhgqCyVe', '6S0BIiWtnqU0PtumXMpin0',
#        '1V5vQRMWTNGmqwxY8jMVou', '4Dgxy95K9BWkDUvQPTaYBb',
#        '1Xsprdt1q9rOzTic7b9zYM', '1QRIX6BuSGegYwiAZOv4R5',
#        '0u3x6X6FRE23fJEhPJoo6Q', '4rBHg7R3tDXJirsOrp4vG4',
#        '1hC2L9ZBeCSUsh6w3xzqN7', '5gsTckUr9I4z7uFHMheffb',
#        '4ZxNekqkeVlCYcNdD0mnD7', '6WivmTXugLZLmAWnZhlz7g',
#        '63dnCQnCOfPpLQU1aZvKE7', '31Q7DQ751hbCO98r1ODhGt',
#        '3yHOaiXecTJVUdn7mApZ48', '5KMP6XLSrhsswEuN2A9VO2',
#        '3vj4CZBV73qyxuOaJM8QG9', '0iXucqK60aDt0xxI79YZiD',
#        '1fWvu6l54on5kRfgaAkedM', '344VAXCsawRmlsrHtcc4pQ',
#        '7xd1ouQwXMKqntXUduWFP4', '0loOZXQoeYJ1IF7sjMCv56',
#        '41tuX6tPuCwAbFhQCGR720', '4OUg8wmqAxUfSN05i4um9Y',
#        '2NEs5bVvRsZdlFkF3XSad6', '6EdIRW9aibRlbaV6ZOppNr',
#        '7E5EsKr2uOyPRvw4nw2mvW', '4sqHRbpZAYZrfsglRPaAfM',
#        '27LNgTSAGxE2fitrsCukmT', '4v48ZVHiC4bhrxSFTTbU7Z',
#        '0EFitK3T7hqin7iGMbpltM', '0e87bN6benf8fhvqtcly35',
#        '1SUZhiJWtX4NKS0KChC0vf', '2NQkuJ8jEuusrkKkWkVQCo',
#        '3d7xzl9F5kB5quLHUVI20I', '4sRUr5XaJYlc17t4jUrqYB',
#        '490NgrGvR5PX8hWK6bUNsy', '1gq1Q9wDoI8xqBG0x0HxSu',
#        '5BAukn6AWk5tubfqjtN8gd', '76HLskcIOsNyVTdNV6k7aJ',
#        '3woYZI2bFXEh5nR8KfltJ1', '6zBBxLIHn9cIn6nSLA10B6',
#        '6QUYb9bb2XTcoM4O5qKRGR', '0OZ5baLiodw7bWaafAjLNC',
#        '2ajzmevYDNE47Yy9l0qtQU', '0SsFgST749MQC6oN9PLHLf',
#        '31MXuVpf2Ebm8pZHgR8VKQ', '6cZwtjs5mqLDPi239S2rMR',
#        '5eHtrrcmgVnAPfOY7cE6K0', '7LRfrmhkp301VsTrYiiXuu',
#        '2RW4rSSY2ifjnkdC8ESIco', '5hEpJAnE6SPm4CDnjGt3OL',
#        '7At6mG0vv1DWLVuRrRr3S0', '4b7iBQ6FtAoFDJTWGGnCRK',
#        '2T06RHWicMtCA5UdHXrg4K', '0dyOEzcIJFeQEkq6nRB9j7',
#        '2jkTb62f8NGNLmiEWKPeD2', '42j41uUwuHZT3bnedq2XtM',
#        '09AkhNYWocEZWbeYl1YBf7', '1E2bKZBFR7hTl0hg8nUkdr',
#        '2OPcQNLP8DQVumD8kBRAH3', '3vwhtBspoJYUhNjQs47ztR',
#        '3n4DlItnFse4pNj8jddEXf', '1dIQCUmv1flCLWByivrbxQ',
#        '5Upjd2sQh4iJnWyJgi3TsA', '5Cxb1CkdXhBzpPP1w9PF2X',
#        '2zCvRv41iZ52TYSy1OHnDl', '4D6BtgzCwuJx9omikqA8Rg',
#        '6Do68lYD1UfOmeBYtsxF18', '6QN8oDUg0dJ8pguyXEO1ZE',
#        '1FhmTMNe8AziAPkB29114F', '51pSyGziPFv8ajzF7ilUAr',
#        '10KjUArbSYS7VCcTNbnVxS', '5CNckxfLf4TCoMOoxgAU8l',
#        '2NBVxjZcbH5H1N1Ab2ExDH', '32wYrmt3fg2c8maA80Ioc2',
#        '6GAOLXEbg4J8BhY1l6FwC4', '3eDVErNq4ndfTbqmdIdSaD',
#        '0MNPF6dmnLWxPypu6wVJH5', '1nAlWYaan9APun2GhGtKrT',
#        '326psP32W30JecUiuuQNjn', '4jtp3iWaP6STnG9AmhOEZi',
#        '37NNM6qLR3smpLIJZz1vny', '5ESsMrqbpVnksVH6lP434b',
#        '6KRuDKhT9wAqAZ1k7NzUWT', '3QgFzksD4J43TnGIJOOrRV',
#        '2gF8vemxCNFFMK8CJZ9pP3', '3TaKGL2a2HRrjMIS8Z0Io3',
#        '3kiNeQg790Wcg7QlUqdgj8', '4d2YOjyPDopVhOkksaALJj',
#        '1XBX4A7VQl4ryuamIqnpgn', '7y3BNyJwbGO7jdShFpChQ9',
#        '6dp5XQ5PKCHupK8EsXjMcD', '1O60vXLCoOznFweoATKZR8',
#        '0JWZvxiJLvRQwqKL2IhcD0', '5WfM4Cm6YmThxnPQOjMsIz',
#        '1FLrsF9bDYIgYY6ewTrvRT', '6VrXK0bcAMZNbWaUwIQjYG',
#        '0XzHfgLEQ5IODfpGhD78Sp', '537bCyj2TPs1DJOJnFTwZr',
#        '1e97vaQCuuZH9515xaj2cd', '2NUSMc4rQ9jjUFE3PnhKBO',
#        '2I2RZ34NQn6QnBP8tBjolC', '3Tgn7LcTsR9nM0IapZC8pM',
#        '2sHGpBiyWeVw8VDBAvaX5X', '1i2TYhut2Dbj45TwTHBRW8',
#        '24w7MWobHrfHggTrbw8jYD', '7wHKtsDZDqB8lowJGe4vgp',
#        '6Tto9pCgT6zC8gNktupelD', '72YYml22WMaAeYhiWX2f0n',
#        '6I0yWpswuJBFg54YJbdHo9', '5WPE0c5STIaPTLHt8W7lTG',
#        '5m9fDPZCm58HqJV2WIN6Rq', '4R9EFH7hNsbqb72nTH03fv',
#        '5ndyt6BTl4AUvWZcB9RIL7', '7oGP5jNEe8NB27eAibedx2',
#        '6SpMfyLwixqP4lG13cYvLi', '603GdeqYWAz5miyGU3OyMU',
#        '7bWnJ3gC4PredxzX4cSvE6', '66oEbwkkeDLz8YH9PwDzyb',
#        '6xNc1eayrC0hSoO1aVMUun', '6X35yl6P8sUJswnKEtOCcD',
#        '3BslqnfoYYM0dNYgGrlKXi', '6LWZUjcdSSbfn4QDuZ7rlC',
#        '0VUmOXzJDx2QF7Af0Qurd7', '4YnZbUtBK4xEkh9ib1venx',
#        '2zddBkoDgJQWaLvwapwFDe', '5J3BLbNa5vaSJGa0R1vu23',
#        '4hOz61gXqf2tRrBD7nORYU', '4upe35RrCCjcUTtjSh2gy5',
#        '0m9qXUFXDiu5xIL84C6hIH', '4f9XFj1HjgVJZeOGQYI1jJ',
#        '7C8RemcfigjV1itpGdsmzM', '2CozmzNuftjJ63VnwcHXw4',
#        '4LIvLGYH1ZGsydvRZOu2Jn', '2yRTNmJZIuhGgmeE43bDQC',
#        '1zbR9wF75V1TmLwduhUTg6', '0HbbWsuC5YOU927PIhyBnA',
#        '186QgVrzAjUEsPx2mD4XMm', '2fvEjqeSepUFLyYxOILp2F',
#        '3kv9cfpmyx5pJL2RuBW1ke', '63SwZU3t9Bqb45SVWoPprT',
#        '2gwkcvo9U65dK4FBqtkDqh', '4wngUMjPQwiOngxqKPuh5p',
#        '5hAD4LXxxdchtucBuXa8Gp', '5XHvSgcyEK3a99SwDyvppN',
#        '6WOef5aZlHawN6OfRbpeAR', '4TvuXrfFiGnBOcNcwVhr7t',
#        '2Vx9FC6Um8i6kEtY7HNswB', '0zHb7F613s95pFWQhgXQ9w',
#        '0dXzrOfFmSXgqqnSA9r3dN', '0tstTxkR8uow4hBYgEgOAp',
#        '4NZWRpoMuXaHU7csTjWdB5', '1sxqYNzozsrgu0Vh6jQ6Lr',
#        '6pFOh9PfVU4NUycoWYkEl2', '7sqDTErkdvj5PXtO3qkzJJ',
#        '3qlsaBEeDiCqv15PWB7UjI', '1dhQSxmp5SM5bLyssnqyk4',
#        '21m7s6qWpksbj6l08OM7Pu', '1Ya2L1SaukipRj53e0dIYc',
#        '1yc3Ldus5BkJBVX9mSFMt4', '54dY3hrGWMOSPpUGZZJbFR',
#        '3d6ydK5AhL3xgq2LIzp6yd', '2PMPiUXeES9T2ujeUHzrpw',
#        '6TtycqPPwkFce4Hx7opOAJ', '4AN7UWH04E737wsJZHfhjP',
#        '5w22XGr5Z2yOHy4UdLrmqt', '7h26nttvLiSB7a3oojF36V',
#        '4xwmzc2g4a5yv7yRxCQ91V', '4vPi417GIyreDLamFQVZJd',
#        '3xte1n53BcjUBxr8BBHdHq', '1rWqOpBKbCoxUvirPmBKXg',
#        '6JQL2t9IAlKOShcOf147wn', '16h6wTeHx3O3puzLu7Rvzf',
#        '4vT4X56azMSUuvAuIbL6Nw', '21R2CiMVZH2MY514Sq2DIG',
#        '5HAwYvpJxq5J9US034C5gl', '638FpXZjBTO9b7haAlhtU2',
#        '5umCH0AoNKwl7R4TtEK8Zt', '0hvr8IdynQ1X1LHo3ahfii',
#        '0cFTv5Is5TmpNu6PkVvlsg', '0veJ44hugjYNglYR5RociA',
#        '53MMpgzZgob6FH9qrPukWl', '7vxRFIBkK21ZBSyMoK8xvX',
#        '14x5s1nB8kcYux35te5f1o', '3EySTlMIX3ZDV7yEZmtCqv',
#        '3I5wfl3oMHg5ougMUuOuDU', '2ozSogRt70olo7s0KlXLzi',
#        '0i7gI9SlKIZxdz2Jl2dyfp', '5GH8Szn1e0Wb8RRriOoGGp',
#        '6sC4PlgvhDaQrqFdeROIga', '6J8yOk3Yzjf9g4EfyATsk5',
#        '4L9wYBGd1WxSFUrwLT1gvg', '0R9hEjnIeXJ7a0EbfO3TRe',
#        '2SykBFe2m6T1xVjyGnB3EU', '0pGirWyas6rVnBnhbiYgp7',
#        '04aSmz3QKJZDy9llsMz7YU', '0j0EQ5lvPM9c0OqqIyaIBC',
#        '0q1iCP7zlNEHcTIvovdCKj', '0OcJozjLfwwwzbQJwJJXtS',
#        '7BlVERnuLpR9gQmYz2IzoY', '3YmRhKciEU36Qh6MvOxDTC',
#        '14qZ1kKG6UoQnBupQTtYRq', '65kmQuUqkUbglq0S707HXN',
#        '7tTNzby7YorAATb7MbnSGh', '6HLEbr4tLaBfiE8IySjWYl',
#        '3a6or8qwEaFtPZFhEWVOTQ', '7tGsKnbjnlYSiTzb7aHbvC',
#        '3yOleyz5IZOlXDbRG072tY', '2EfibOMCoqEvr86D9dvAg8',
#        '077aDqaJwL8a4OA8pKVe0V', '09R4Ba8w5gSdyOr6h31M8N',
#        '4U0pbefjWHLyi8gmzUsW8U', '1WwtSIDqAVe2GnpzVtEtlr',
#        '0ERPnnFfn3LXI3H1C9NuaK', '2kUwfpzYJo2ByMJD7Zkojr',
#        '0URoBA9pf5Byd9Aa8bTcWR', '3Oplh88NHsDDfMLbhAHQRb',
#        '3pqoVYGXSiuYTJfnVrzLI3', '4jRPbkVxXKJvX8DPWS5JJv',
#        '0p15cinXXZeQYFPGWGx29M', '10R5vJyQjoQaFC6o5XB3oJ',
#        '5skhJX1TSsffQPe92dy4bk', '56zLfjE4W8IXFlBlTkvOWs',
#        '6eGJWNKdOYkBQlKz54QIfN', '1VMwGsdHzYNjZpKqMrOrMA',
#        '0xN0qOg7PD2d1t1nToSf4o', '3xdTckJjSyCfWePM4DrTOc',
#        '11wxZcV2j6SW4DYzZiyZ53', '1eHRC2xlILqmuccbZ98bOV',
#        '11t8YvJjQYvMKSkG7vxi5W', '1jEDXLb6kBWox2h2DqH6I1',
#        '3iQA1JZdZwhJBPcSc49ogE', '3ryK3lfTB9KcFC876ykgAy',
#        '6n7Pk0uvNvOAlBBamgFzER', '7G3BLeVhYu29HHOazoQixC',
#        '7qjUz8e7jzTUPLbg17J8zc', '22AFyeP7jjnQbvfCyzD0tH',
#        '7wWG5OxqO5icixq1qDnVlw', '2NKyVWarvc0hcCxeaPvpZc',
#        '6cbYPzA3cmYlQD0JqsOjEQ', '1RVXVo1puacM8aQ6hgQahi',
#        '23EOyjnP1w0mP8LCGOAitG', '2VmLk5bAd5QjLtX7cHm594',
#        '5S0usnelhQktyIh38atMnF', '7MKTridzvKwVhek9wHKsjH',
#        '3dJayNdYjBZFVgR5nbGgo5', '4fjhNjYSjiqetOAYrMqKls',
#        '2hclsmUCroeaplxCYngj96', '0T25V1mum4sM5Ns6t36lJK',
#        '5UNJ28ZhvkXmf4iVfzwppt', '5CvGaa7ehTBOhyxLDxRWb6',
#        '6w0Xa0dgNMyD16KxeaC0c8', '1voOnpa4pILlDPVsrIFl8b',
#        '4Ay7sLXxJO8sPhOyNlmP1P', '1mTEDq5qWNQuWdgrQLI1eg',
#        '7MUsABOX2zbnuEh2kYGJp7', '2aYokx2jGun9pPjyY5Cc9t',
#        '1kaQClLOAmvOeoUXStuOAQ', '3sGhny7zoKJrmEuVblwZap',
#        '143cxYCazoiNfviHRmxkdv', '7HMdyUE2TJOW16A3gClgAm',
#        '3FIOrKEgeQmKlpm96t0b4L', '5EyTrWCxrXgg0PpQzRe06x',
#        '79ulcmh9AHGYehFkmEIYQw', '4HH1KIbSLvGVxfTisuExeT',
#        '4tQjkSBRySYGLLIrppt2v7', '3fLyVygsOa9KL5OqdiX8Va',
#        '3S4AdYSlrxNmmxe6CjTHmT', '3asXE8koS98nGPVDSPKe5e',
#        '10TGSwSd3ahQtPRcwl59cq', '2AKdYmMhcMuZqh3IZ3Uoiz',
#        '5puzQhxisgcpTgZxCHh7F2', '7fhmg5K8w3IhqXki4tJNra',
#        '36xFFPWgnReh30UEViPoYD', '3OusOxKyeaUz5Mqt8RrM4R',
#        '4Wl7wTVnFFyXUAje4uTcMM', '7xnWbcMZGmaJ9RGvYJMnX3',
#        '4anCzbRMoeOoXW7qgAuN9I', '0IP1hWWp4viLp8C7HJew06',
#        '3yHOBVuWWvaOuUPF8A0twU', '0JztR8J9AtC0W7SStwV3ZS',
#        '6QMGlRWaj2nZ43cyeub97z', '2Lndm8Sa4h8Zj59fk6Dtjl',
#        '6DcjgwmNJdsl2BODdwPOH6', '5gsWgFeHRxRkIXGXWPiOIW',
#        '0dQP8epDhkpNl1iGTxY9pu', '59ePhOhLFvSOFG4L5FRGzp',
#        '4GeJssW5iLOSLOIXhLfOUJ', '5IWyGR3IAvSqxdhHSNp9qt',
#        '6NqVZuFGxaUOCWdoUDwCI8', '6gKFILGhTU67b06oNSSR43',
#        '0CBezlC6aZNKVf2554t53k', '2neKEhAldnGfCDEkPE4kW0',
#        '0PH8RsRLAoyOdP0e130OHN', '6ciIitnPuPVGgmiAA3lGuq',
#        '6QMrBMZCWR73bVS8K2MPVE', '0bvZHrg1KM0jeoVOSUnMgM',
#        '5c5n5tUSXcYt61elctBZMo', '69AV8jQqtFuAjtm4Zb7vXg',
#        '77spqXa3VNN0mw13PgWWyY', '2njb3cHa1yhUMdu8PT2VhY',
#        '0bBHLytjtuHYxKxuAE5G5G', '2R5PAxygJ4YeRuSwoalKam',
#        '52WqC6vXDQ9anMNugsUCeO', '4u1IZuRRLb6tkP14kvAkGw',
#        '1jbg4grojEFWidZQZRRcJk', '0EJVUQGqNRxYBBCS0OLqY7',
#        '4WZiQjmX5wVzQV7Aqk9AVP', '7E1BiscM3O6aifwtcLdUG7',
#        '3GEik2gbuXtRIKyYYvn2WV', '21pC8GFru8M98MhMCWONk9',
#        '5uMLCobPh02IG3fyH0Dzec', '0U3pSVpKsVH2lIbNuVJKoI',
#        '5xpXkqZo7ljnrvWSMpxxOn', '052CF6cpp0nAH67yuUrIp7',
#        '4vLpAl3eThYWwJCX0Ru3DD', '28fqmcfV4mpPsqhdNKUeTc',
#        '67qNNUSHekqSliS7Q1XZj6', '5ciyHwetCfRiFA4BS7SMKO',
#        '5aG9PNqK9jLLJoehlNXlwW', '2OWY8X9HTnG6srfrO76bBL',
#        '74KxbVHBLgcsm6Ekr8arwd', '6NUcdndmwC54yLd0KosGI2',
#        '31FV0sSOdWNOKgOHQefZ6M', '79lKE9hAYu7G3Mn9hFXPeY',
#        '1zsufhuFqUpaqSbWpAWhvK', '1FGFqkB35zDg0TtrJJWNqW',
#        '1sQn79gifQ4VeR8FHDECme', '3Yl5E4IlQOVDr7xV6I76hY',
#        '0B2uPPBGgCOJ6ZvxGWVTw9', '1YEKN0Bpeo0i0coa5niw9F',
#        '5txz8rm3pM2peZ3K8oPNd3', '5Cqbb3avfrpSH4EQS6fORX',
#        '6UbNzec69vmBfLtzFywR7I', '1d5q8a4pbVi12UrhI3Kury',
#        '3OU2G4eb97eM1lMvhSWFvf', '5gnWhEFNbtCn0RLG2cp90g',
#        '4aHakdIA1e8HoRRUsYszDY', '4w5Jvreahp3yvLqc4vCr9I',
#        '6nBXl4WJtnGtcA1QUAC2lM', '0qOpKQX8DBZaI6lhXv5aa0',
#        '0P8aZWnqAquGohixYHXoTL', '4ykbJPI8MPscFzROE8dqLy',
#        '5EJgQd6IcN7xvdmpARRk5b', '2ZHYOFW5giX6a4n5eqTnUB',
#        '65vvyHtiPwv9xiQFRdmjoM', '4sSCuPTJst3sfhHRvC76Ra',
#        '6BOJ3r1s8u63at3Ou7HaVw', '7u1Tix9DQQ5he0AESSfGkp',
#        '0YgJpsCDakroRHWZ8WzgiT', '4Q9RAjO1YjXgn5ErqvoNnS',
#        '5V2XmMjFj67jL0Hsd7OxUY', '73DvNFFJZKhPbbI9EZb7hF',
#        '0gwoPCg4vqOECKqowDHTRz', '0Ynpbu4iLnqdFkfLHAjnWz',
#        '5cy16pBwsgoLDcpoMFPzDv', '12pZaG66bDXN3XRjF5rlGB',
#        '3uQBcPouETxmmNmYSpMqUY', '6NUEU1vyIctdAg8IHot8Wy',
#        '2kUXqmlthYkv0yyW3N9cy8', '0WtCqmpVN7rRGfDMSWSXBA',
#        '6OOTRO7lfMvDFQzNXby9i8', '7lerMohLdPa3WIdXE9sH5p',
#        '5M8gr5RV2eR6UkztC69ogB', '7fbh9n3m228iTvphr40LJN',
#        '5uXnz1avW5OxFmroX5eSBu', '54ZCcmTHjghuPkzFYJzPGf',
#        '5IyIjKnGkQbYGVpWenblSe', '4ybWq0AegFFAvHULAe7q0K',
#        '5zqme5HHaQXfVwIl8SMs5W', '1pL0MPgFZlRnM7OVoX8D3f',
#        '4DkSAOFnWkgrXske8pzELq', '13pqUKo7eRvMKFGpfCGyEF',
#        '2WqHN90AQgk95Str6hWCt9', '5W0yU7K2XCMYGRw4Sc9xOx',
#        '5vPxkMnXCTzQ55LrzAjT7V', '7r8cDmr9uO22qvpR8IaWhS',
#        '3KywI7OReNXNcDvZn8I6fg', '0JzXywsekILWEm0mBPKKhC',
#        '3bfiRIuAQ9SGM7DG0xgp52', '08IaIcoTFnWKroZgUY3Ezp',
#        '6x0EDAffuFSBcwupP2m4P8', '1LqxKSLjw1BiTPS036wg8S',
#        '1AdPT0WwlsXejXahAEldhy', '4B1IUKpspjSVnqYtcht4WY',
#        '3dND43Z5k5wn5sJHGgz5mZ', '2ny0Q7DWoI2GH1TlQTuBdD',
#        '1DTBcVfk3zXPHRmgpY6rFZ', '06gZYBNkDbO8Rl36rbMvkW',
#        '7Fgy4IcWQY2W3bgcZ74XAK', '1aQW9ioTHpbORrlixwcv2j',
#        '5Em0z535tLjqboM09L88B6', '49MZjKQcooZ8zJzMKPjbas',
#        '7ETSgNWJBBsjscYnuyGV1b', '2doxS53qPZtV4AnpXFg3Bi',
#        '5CkGOdgj9Ajwt2yeoAVRhc', '5Oy4LUESdrOchyGcLup9qi',
#        '55zg331p7m1EFA4uRggkwt', '6ge0V8IXA7yL1SUSIAfAzO',
#        '0GzsdiiItPCABfhuFIKiZi', '1SN6N3fNkZk5oXQ9X46QZ3',
#        '2YtdV4AkQesuqE6UwSADk7', '4ow6xJwn49gpWz7iHpOzWY',
#        '6lMlX68jJrx67hiCqdiDvW', '1alDPx3BdkU4YBHRZ8gGLu',
#        '2oCs0DGTsRO98Gh5ZSl2Cx', '35Cuz13gq76FoBKrEMlYTT',
#        '5Nux7ozBJ5KJ02QYWwrneR', '02drHFQa59AoJWU6DXSSjd',
#        '7bRlnYERYzmXE5ljBfk2v6', '31duzWUmsXuuXpV9qfi536',
#        '7huML9zDbY4thKH0xSuZTP', '6GY8rrxuEzSJI08F0rfigi',
#        '5V5T5fcIXdGH01QNFWEX69', '5a5VMT422hJIl5urrANVtm',
#        '27yyZeg059R0ilMJFkGe59', '0Rm1cldwNQE70AnlRCT279',
#        '59afW16lg1vvJ3emrlSHTp', '21z9FNiaJZpICt53krDAby',
#        '5xbtrUflu3wNjGVaLgaxDf', '7yCXgxWLZZEAiVsISKN3BF',
#        '6KIMD5cU71Cu9JMgnfDrLD', '1l7lrQ0vspjRE1OWwzKEaP',
#        '2ZIRZhIyxyVisUU5haXdHE', '3OqxBPBIqKrzJjeUNZcXnd',
#        '4Fo44gv52Ckq6S1NW7cjx9', '63iWSELt9V1kV6RSMxN7Ii',
#        '6Fr2rQkZ383FcMqFyT7yPr', '3jJ5HhbOC2KB5fOZ2RgJTo',
#        '1rknZw4cyL9NInAqSwc8AA', '7Cz0XcQzoxUi7L7sfgXLml',
#        '4yz9rO7Q1UC2rK5eLOxmS7', '1RMfz6rbIyrQYChfcCoiJ4',
#        '5cxMa6oLINJzmZ8lF7wWQN', '70f70xLCpH7wHaVvB2oZT9',
#        '1ewP1pI4qMOpd5GJCSzSFM', '0wZJCeyfJ0LVrrtH4CwQYw',
#        '67yocJ5ii5veHPFAayupUM', '3cr4Xgz8nnfp7iYbVqwzzH',
#        '0sH0tKZWzQlRVGv9rcwYEp', '6CfqnSKx0p1GCjdRpY0JAS',
#        '63MKT9hwmiMFFdFp5SdB1p', '790wpCevrVtF2E6wMYHqFc',
#        '3BmcYMh0KYsimWL6p2gPa9', '0ALfQaGYSvcRNV5OLbixA3',
#        '0LFbHl14nV9InXzoj9qV33', '1frzMyOTpRjXVJv476f9LU',
#        '1rG5TDs3jYh6OU753I54CI', '0sTWDNDdByvpadJqLYTR2U',
#        '0T2XUrfe6kTPn9R41TQYnF', '1imXAvLuowvPYIsFMYUPY0',
#        '0Whkv3Bi9hP9ev2cFPlZR3', '10VX50yto90Re5sFwoyz3p',
#        '1Uu0gCSEPnNj099VWt2eQk', '1NXzlVvFqPATxSheVsEVZT',
#        '05Bru0ZVTxp4orAyrZIA77', '3BjxjIkTZKUpeZ6n5MYMNx',
#        '71znMnnyOF4NIe4UpTYbw7', '1GHkv48TNqI8MKWJ1FwKFC',
#        '6OGBP8kekV91cG9sghPEVw', '0RDH4M8AhISBHwCVr2ByYX',
#        '5FFIZArVcXAMVjPMUJxBy3', '6Ev0UgdNwWq80Em5jknB95',
#        '2yiy9cd2QktrNvWC2EUi0k', '2oEcytQ5u5QtR9VZc2XgE2',
#        '35pH6Mjv5ZAZ8PAzo8I4da', '3ZQZrCJHXZ1G6EYxzYGhuA',
#        '0kHdDpkkSlesh2UMKhF20G', '4es0SCGoooYKR36713JWNz',
#        '0ccEi0a0jdxn6tTNAnKzAI', '1e0B33rcH0vHHumZofYV3y',
#        '4uoEruXjt0APvHaSqrwqPH', '6Z5DhADmyybfKNdymaPLjB',
#        '3E12WU80fDMyu7GyIAx7wJ', '34hxmcDX91rZtwckrSlq1X',
#        '7ECFU1lKlRqNn0WokJ6VDN', '7057vj3r5jVIlis4uVnP2M',
#        '5GpwroXObdnETiIpVb1l23', '2m5WUxYqXkJc2gdP805IKm',
#        '5IEP2NdoJtkoThS0fkZmap', '2MOs2gBy14kW9jYXbv2A3O',
#        '52kvZcbEDm0v2kWZQXjuuA', '6RLYvSz7Ob7PLAvqxZNjBh',
#        '4uJ318DIOMiA4y9vg2dRwv', '3ZQ5TYGh6ei3IDnQ3GscGh',
#        '6y6RDTPqAox4sTHfy1piVX', '2EexX71aSkFuYuRMwgWKkn',
#        '14mR6XKPmsxzvOYCkqubJF', '0gPq8o2JsJyVUyxzMITWBZ',
#        '6LhLsGjkUVzAuywuuFIkdu', '77lUgFzLJriGpyTx2pGbCO',
#        '0LWRykrSX54AWiMZlV5uUk', '59KxIJM9NhO7kVYyh26Ulg',
#        '5j1qqBBmxrDu58pYAj8r9v', '6m47Bv7lQlUWNZ5W6N4XjJ',
#        '3Zq8gpa3P0UM8H6XIY39Sn', '5Nk90vGwn59ToxTvSNsKZw',
#        '6K5S3fWJ6logqsusWVaJUG', '5YnGwVQx2OQ4CpcQeVDthP',
#        '7oJa8bPFKVbq4c7NswXHw8', '7aPgDPIX7ekjSTc1eLmyy8',
#        '5jBBJP31P5ZMdWxo2OKaYt', '42ChI9lOBjrA7bp5q8XwD1',
#        '3NsLmV2pShmAj0k9CySrye', '2WFfiru9h8SlaO5VpiYEP5',
#        '2kumYlTSdm0hGwu1vQ5utY', '4fnNeUsTKQli86EWazLiVZ',
#        '0yJINpqqZPcRQhAnts7rPy', '44a1fzx5dGPT2VKliOw6MG',
#        '47fsIFFdKkT1aibqeiZqe0', '2oVtDZf7Xk3gLY7qN78asX',
#        '358s1FksXk3qh38nNdjJFk', '4DHfWQYwbzWOVmy5euzaFP',
#        '1lauDjICyj7zDpHVur6ro4', '50KbYv9LCZpytz20CHafys',
#        '5Tb4ySF7ow5Zskf5xBVqMi', '2KfgXSt3qzyNjiZLbVlc21',
#        '5HMc8jjJN8kP4Ik06YizEm', '7FUogAgrnR5AlV9aZosZWe',
#        '2ytdzbTDT43a9T3Bjq2njx', '6XDofNPyvBiUK6NLU2W0sv',
#        '27st1Ra1VgUfC2xieLuN7P', '12xWD1Ix0cfktk6Vn2p7VJ',
#        '57nR5cJuiPZl2qBtAQppSJ', '40TWM0OpD4tS3AoWLnUxIC',
#        '6iBvt4DAGNEJwIvM4vLPms', '1xG2R130AOrGv0x1qBga8D',
#        '3j70EKOaR5iVk0BPW6lowR', '2b9Zf72wY6kwvcblYXtB4q',
#        '5DtgUQOe0XsYdyKtP3vBxc', '7jfNbUImln4VF01QtMpe0q',
#        '5WPSOiEAYPP2CAww0MwRK1', '3Zao4egmTSVP5LfAhHO4o1',
#        '6b6NoQ00gDKdOUBxRYTA7t', '3oIFxDIo2fwuk4lwCmFZCx',
#        '5oUZ9TEZR3wOdvqzowuNwl', '3T4tUhGYeRNVUGevb0wThu',
#        '0MeOIA0wwSa6nW79jy8QcZ', '2hyDesSAYNefikDJXlqhPE',
#        '1xn54DMo2qIqBuMqHtUsFd', '0Yi8StK0Si3u2bLr3Qsm2Q',
#        '3hA2oZbZwHU8tSPBFIZhFr', '6NoBzYmh5gUusGPCfg0pct',
#        '4JUtnlZKdLr01xEIymhm0G', '3QbPtoOWiJqZurXXxJwaOD',
#        '1slAnKc9Ykyght8EI9Y0dM', '3w0VffyaakTvUtTwjPCo7Y',
#        '02pi98kE0nra0yBqCStzbC', '2PNtGh8cixtb0oXjbGkUnZ',
#        '0W5GGnapMz0VwemQvJDqa7', '6DpIyaMgt5p9HlGd1c0LDM',
#        '6l7iXnb2Y4yDR9zag3kckA', '5sZIjREu3s225wwqJkgsYV',
#        '2Z2KdJE0nGGu0qdWA45mza', '1iab5rfjNpGhoPlFzPyp4k',
#        '5LGsh3kexUfi3qkIIxb8vK', '5JnnrTE35MQagEnEkFthiF',
#        '6Ou4LWiU2Vu2V7KdHzw9At', '59YCk9wEnWWopdzu4Yh1dJ',
#        '2UfvnX1YYeC2cExMQTMbXC', '531nfs5NPsmkRC1LJb1cdj',
#        '7gU675c7KZ54MzEcL1O3px', '7HEXQkjBNiZilJcTWXwLOA',
#        '74utZeTCeaXy01BjOddyv8', '45fMDoh9dhhQicddIZzhKM',
#        '1Tv3rrFNdXGtTeP1plX2xE', '11e4xCXllbvk8pWc1cCas1',
#        '4T5606j6qpkQrWlwbKPLOp', '7cfhaRiLqBzuAzc6Q24nyW',
#        '2JK0T590oG0pJckY9HRniL', '7vzYp7FrKnTRoktBYsx9SF',
#        '1NAmidJlEaVgA3MpcPFYGq', '6DEjYFkNZh67HP7R9PSZvv',
#        '1MPAXuTVL2Ej5x0JHiSPq8', '1Hrs3jLGexOvBoaPMoOQYJ',
#        '0bEySlRAkuPxV9KVWhXXBr', '4uUAUqIfSomFTbbjGp3TYp',
#        '2QJmrSgbdM35R67eoGQo4j', '7N3xz2HFNVH5BEkm8ZVmoR',
#        '0L3oaZUj3loxosjvugCLGG', '02H4kc9YLgorpUIREOwa0q',
#        '34OkZVpuzBa9y40DCy0LPR', '5LVuISYu2g4YbyxYhFPIbK',
#        '4R3hKmiJWEjRe6l03DoV9t', '6EsTJnpahwW6xX20zvqQgZ',
#        '5fy0X0JmZRZnVa2UEicIOl', '1yGbNOtRIgdIiGHOEBaZWf',
#        '1KlU96Hw9nlvqpBPlSqcTV', '1KVKqWeRuXsJDLTW0VuD29',
#        '1EoDsNmgTLtmwe1BDAVxV5', '7daMnnffzVSbNJj8Dy75Ev',
#        '63lVCnv8B30qedCiTlAc9J', '11gfxXxJPd3j6sdWUyEA5S',
#        '4jTYApZPMapg56gRycOn0D', '5EpMjweRD573ASl7uNiHym',
#        '5MfAxS5zz8MlfROjGQVXhy', '3QXlUpSDgakWZK2WqQv0pF',
#        '1BdjHo5IR6twMhJDxzlpLt', '4ErTrymYK8VIBQR8J8Hjy1',
#        '6fyR4wBPwLHKcRtxgd4sGh', '75N0Z60SNMQbAPYZuxKgWd',
#        '6Ar2o9KCqcyYF9J0aQP3au', '6GPyXXND6hIZpd9bRhCsFv',
#        '6S6JQWzUrJVcJLK4fi74Fw', '3Mvk2LKxfhc2KVSnDYC40I',
#        '6tgMb6LEwb3yj7BdYy462y', '08CWGiv27MVQhYpuTtvx83',
#        '2dqn5yOQWdyGwOpOIi9O4x', '1CYlmaXajTC59VJWSSeE7Y',
#        '6vRfYCQ1mKKfnB6D7R4N5p', '2gP2LMVcIFgVczSJqn340t',
#        '43OpbkiiIxJO8ktIB777Nn', '3EzFY9Rg0PpbADMth746zi',
#        '1rwH2628RIOVM3WMwwO418', '7mzrIsaAjnXihW3InKjlC3',
#        '5eyZZoQEFQWRHkV2xgAeBw', '1mFGeuBwVfAyli6aDoy9OI',
#        '1ymIvQpnPQBj1lGlJRqrFQ', '2rU7u7C2v5i45MFVxx7xG1',
#        '3dbGt0XseArzHevp1kBYHD', '7kXQ0AvaykUJMxR0gRfr4d',
#        '5oj6N6xLROv6pLctdOhENm', '1h8c5s02EHw89eddxInlul',
#        '7IbLnQpLU1n85xtPPr9dbR', '112eEMM7VwHVEknE4hHjjY',
#        '7sg5iqMiDrM2aJqLAmv83V', '2eDQDP6uhkBOtQKctBWXhN',
#        '6Ukmi7AfxNAUrwmVWBwJ1a', '2Pf42OiIQLrA9swcdJGFqv',
#        '7EUGqK1EQw2k02BFR1hu47', '0CvwwhkzMUiDm8cQqtN6Ys',
#        '0u5tyaipbUJjHgkceoPtM7', '2RHYxz7blfHR3iVxPtc25G',
#        '4oCGmYsAQOWt2ACWTpNUU6', '6tBpgZG9bV76nSuiz42RbA',
#        '2B87zXm9bOWvAJdkJBTpzF', '0RprDFd8KN06rt0jyKXBsC',
#        '2nPokmAvYy5qYO4rFU7ZDm', '0rmhjUgoVa17LZuS8xWQ3v',
#        '6rnzvZhe3PA57xKcKLRtJ6', '0FAWfXvd58Rm2VUSZMF8pr',
#        '4XPUXLAWXqM3uWMTucItjd', '71VX8yv9T2hNIYVZJVUWVp',
#        '2CLH9F9W9x1VZaCltWPqXR', '1Fh1gzTOImG12M35w3nqQF',
#        '4KEZoY1iPTxwCsGSm1sGAM', '0iqqnLXoocsMeCYlTw3Q2q',
#        '7uSaHPXSYaRB3FxLOmatG9', '46H4UzFHMLnGgpyrj9HpKr',
#        '5F4I5eUqVK1CpQbzt1ntMC', '7yOOPJjNelITCaYMqk8V6r',
#        '6OGzmhzHcjf0uN9j7dYvZH', '68j4AeI3JdszaZ7mhCh4Yo',
#        '3RYdEXhGHojkTILUdtnRVJ', '5CNvBhVChhDnfy9bkS3fWH',
#        '3TLaFWQDhV1g39Qwd5sPAm', '3mH6qwIy9crq0I9YQbOuDf',
#        '392p3shh2jkxUxY2VHvlH8', '6vzH59tobnxE5WXMiqvBIx',
#        '623Ef2ZEB3Njklix4PC0Rs'], dtype=object)

# %%
album_mistake_df.loc[album_mistake_df['album_id']=='623Ef2ZEB3Njklix4PC0Rs']
# Out:
#                    album_id                               name  total_tracks  \
# 938  623Ef2ZEB3Njklix4PC0Rs  channel ORANGE (Explicit Version)          17.0
#
#     release_date album_type               artist_id  popularity
# 938   2012-01-01      album  2h93pZq0e7k5yf4dywlkpM          72

# %%
mistake_df[mistake_df['popularity'].isnull()]
# Out:
#                     track_id                          name  duration_ms  \
# 500   13K3BqdOYYMepkNQPWL1DZ                        Target       142050
# 501   34S4m6c5KQkPBl7Am9uQQa  Man Down (feat. Chris Brown)       165722
# 502   0aJP5iqcwIMrRerm3SVU9a                   2 Tone Drip       181538
# 503   4mqsUZrSOnMhexy1unMUbv                     Feel Like       185456
# 504   6RFr8aTQDY890SeEPxT7la      Cake (feat. Wiz Khalifa)       165214
# ...                      ...                           ...          ...
# 5545  4H8DlsD6NSGlEwCr3x39Nl                Perfect Places       221874
# 5546  7GRgbc1Dj2NBiZpCc33c7W     Homemade Dynamite - REMIX       214254
# 5547  6ie2Bw3xLj2JcGowOlcMhb                   Green Light       234652
# 5548  7eElVgPcxDqmgGrSwVFI74                         Sober       197235
# 5549  02oAUzv4M0ItuTDy2RT3IT             Homemade Dynamite       189796
#
#       explicit                album_id  popularity  tempo  energy  \
# 500       True  6l4itLa2SkBAVBASZ2WKFv         NaN    NaN     NaN
# 501       True  6l4itLa2SkBAVBASZ2WKFv         NaN    NaN     NaN
# 502       True  6l4itLa2SkBAVBASZ2WKFv         NaN    NaN     NaN
# 503       True  6l4itLa2SkBAVBASZ2WKFv         NaN    NaN     NaN
# 504       True  6l4itLa2SkBAVBASZ2WKFv         NaN    NaN     NaN
# ...        ...                     ...         ...    ...     ...
# 5545     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5546     False  6tBpgZG9bV76nSuiz42RbA         NaN    NaN     NaN
# 5547     False  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
# 5548      True  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
# 5549      True  2B87zXm9bOWvAJdkJBTpzF         NaN    NaN     NaN
#
#       acousticness  danceability
# 500            NaN           NaN
# 501            NaN           NaN
# 502            NaN           NaN
# 503            NaN           NaN
# 504            NaN           NaN
# ...            ...           ...
# 5545           NaN           NaN
# 5546           NaN           NaN
# 5547           NaN           NaN
# 5548           NaN           NaN
# 5549           NaN           NaN
#
# [550 rows x 10 columns]

# %%
#enter credentials to upload to a mysql database 
engine = create_engine("mysql://admin:sql_2020@lmu-sql1.crhm3n8rz1ea.us-east-2.rds.amazonaws.com/sql_project?charset=utf8"
                      )

# %%
mistake_df.to_sql('track', engine, if_exists = 'replace', index=False)

# %%
#add each df to a table in your datbase
track_df.to_sql('track', engine, if_exists = 'replace', index=False) 
album_df.to_sql('album', engine, if_exists = 'replace', index=False)
artist_df.to_sql('artist', engine, if_exists = 'replace', index=False)

# %% [markdown]
# ## Script Notes

# %% [markdown]
# ### Search Functions
# Because more than one artist can appear when an artist is searched and
# the search results aren't necessarily ranked, I have decided to find the search result with the
# most amount of followers and return that artist as the "true artist" when determining ID's. This
# assumes that the "true artist" will be the one with the most followers as it is the best metric
# available. If this were a real music festival, we would have thse ID's on hand to be 100% sure
# we are referencing the right artist. However, this lets me use spotify's search endpoint and save
# some time in the process.
